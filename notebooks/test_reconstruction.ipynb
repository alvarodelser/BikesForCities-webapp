# %%
import sys, pathlib

ROOT = pathlib.Path.cwd().parent          # one level up from notebooks/
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("Project root added =>", ROOT)
from app.database.network_io import connect_db, get_or_create_network
from app.processing.network_ops import reconstruct_graph
import networkx as nx
import osmnx as ox
conn = connect_db()
network_id = get_or_create_network(conn, "Madrid")   # should return the same ID as before
G = reconstruct_graph(conn, network_id)
ox.plot_graph(G)
conn.close()
# Out:
# Project root added => /Users/alvarodelser/Projects/BikesForCitiesBackend
